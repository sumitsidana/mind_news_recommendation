# %%
import pandas as pd

# %%
test_behaviors = pd.read_csv\
('/Users/sumitsidana/Downloads/MIND_news_recommendation_dataset/MINDlarge_test/behaviors.tsv', delimiter = "\t"\
, names = ['impression_id', 'user_id', 'time', 'history', 'impressions'])

# %%
test_behaviors
# Out:
#          impression_id  user_id                    time  \
# 0                    1   U64099  11/19/2019 11:37:45 AM
# 1                    2  U231077   11/19/2019 5:28:08 AM
# 2                    3  U606012   11/19/2019 4:46:23 AM
# 3                    4  U320649   11/21/2019 6:03:51 AM
# 4                    5  U357840  11/22/2019 10:36:19 AM
# ...                ...      ...                     ...
# 2370722        2370723  U584874   11/21/2019 6:35:29 AM
# 2370723        2370724  U584857   11/22/2019 7:13:47 AM
# 2370724        2370725  U160629  11/20/2019 10:38:57 PM
# 2370725        2370726  U406290   11/21/2019 8:24:26 AM
# 2370726        2370727  U268599   11/18/2019 8:07:46 AM
#
#                                                    history  \
# 0        N121133 N104200 N43255 N55860 N128965 N38014 N...
# 1        N45124 N84730 N45128 N104312 N70022 N99111 N26...
# 2        N59893 N84662 N90686 N33265 N127225 N120859 N6...
# ...

# %%
t_b = test_behaviors[['impression_id', 'impressions']]

# %%
t_b['predictions'] = t_b['impressions'].str.split(' ')
# Out:
# /Users/sumitsidana/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def return_index(lst):
    index_str = '['
    for elem in lst[:-1]:
        index_str = index_str + str(lst.index(elem) + 1)+ ','
    index_str = index_str + str(lst.index(lst[-1])+1) + ']'
    return index_str

# %%
def get_labels(lst):
    labels_list = '['
    
    for elem in lst[:-1]:
        label = float(elem.split('-')[1])
        labels_list = labels_list + str(label) +","
    last_label = float(lst[-1].split('-')[1])
    labels_list = labels_list + str(last_label)+']'
    return labels_list

# %%
# !/Users/sumitsidana/anaconda3/bin/python -m pip install ray swifter
# Out:
# ...
#      |████████████████████████████████| 73.5MB 8.3MB/s eta 0:00:012
# ...
#   Using cached https://files.pythonhosted.org/packages/7c/07/ad5bda46a33f1d869eaf71f431615111f251adfbceb4e3a02d66ad402582/swifter-1.0.3-py3-none-any.whl
# ...
#      |████████████████████████████████| 276kB 8.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 81kB 9.0MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/aa/3e/d18f2c04cf2b528e18515999b0c8e698c136db78f62df34eee89cee205f1/psutil-5.7.2.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/6e/77/fcf6c640058c7f8daa7353d36cad5611b23a1085a11c455922d511834b0f/modin-0.8.0-py3-none-macosx_10_9_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/96/7c/3993c5af2ebf2c0b9a88e6028def75efb128c7e163b13a3398c40ca447e9/dask-2.23.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/9a/1e/7d6cb3b27cd2c490558349ca5d5cc05b390b017da1c704cac807ac8bd9fb/bleach-3.1.5-py2.py3-none-any.whl
# ...

# %%
import sys
sys.executable
# Out:
# '/Users/sumitsidana/anaconda3/bin/python'

# %%
import swifter

# %%
t_b['indexes'] = t_b['predictions'].swifter.allow_dask_on_strings().apply(lambda x: return_index(x))
# Out:
# ...
# /Users/sumitsidana/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
t_b[['impression_id', 'indexes']].to_csv('/Users/sumitsidana/Downloads/\
MIND_news_recommendation_dataset/mind_news_recommendation/\
res/test_predictions/prediction.txt',\
                                         index = False, header = None, sep = ' ')
